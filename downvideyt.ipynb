# %%
import csv
from pytube import YouTube

def download_youtube_videos_from_csv(csv_file, output_path):
    with open(csv_file, 'r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip header row if present
        
        for row in csv_reader:
            video_url = row[0]
            try:
                YouTube(video_url).streams.first().download(output_path)
                print(f"Downloaded: {video_url}")
            except Exception as e:
                print(f"Error downloading {video_url}: {str(e)}")

# Example usage
csv_file = 'links.csv'  # Path to the CSV file containing video URLs
output_path = 'fvalue'  # Output directory

download_youtube_videos_from_csv(csv_file, output_path)
# Out:
# Downloaded: https://www.youtube.com/watch?v=1Q2kVCcRnGg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 21
#      18 csv_file = 'links.csv'  # Path to the CSV file containing video URLs
#      19 output_path = 'fvalue'  # Output directory
# ---> 21 download_youtube_videos_from_csv(csv_file, output_path)
#
# Cell In[3], line 10, in download_youtube_videos_from_csv(csv_file, output_path)
#       7 next(csv_reader)  # Skip header row if present
#       9 for row in csv_reader:
# ---> 10     video_url = row[0]
#      11     try:
#      12         YouTube(video_url).streams.first().download(output_path)
#
# IndexError: list index out of range

# %%
import sys
sys.path.append( 'I:\Mi unidad\Developer\python\Tools' )

# import csv
# from pytube import YouTube
from  adlc_tools import web_request
 
# 1 simple
# 2 csv
# 3 playlist


def download_youtube_video(yt_video_url, resolution):
      
    youtube = YouTube(yt_video_url)
    video = youtube.streams.filter(res=resolution).first()
    video.download
    print(f"Downloaded: {yt_video_url}")            
                
def download_multi_youtube_videos(csv_file, output_path, resolution):
    with open(csv_file, 'r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader)  # Skip header row if present
        
        for row in csv_reader:
            video_url = row[0]
            try:
                youtube = YouTube(video_url)
                video = youtube.streams.filter(res=resolution).first()
                if video is None:
                    print(f"No video available for resolution: {resolution} - Skipping: {video_url}")
                    continue
                video.download(output_path)
                print(f"Downloaded: {video_url}")
            except Exception as e:
                print(f"Error downloading {video_url}: {str(e)}")

def download_youtube_playlist(yt_playlist_url, output_path, resolution):

# Example usage
 

def main():
    url = 'https://www.youtube.com/playlist?list=PLl0F5BiXXoP_ATn__Vu7vpvxOaKmspIIi'
    keyword = "watch"
    obj = ""
    link_list = "I:\Mi unidad\Developer\python\Tools\link-extract\links_page-video_s1.csv"
    playlist_url = "https://www.youtube.com/playlist?list=PLl0F5BiXXoP_ATn__Vu7vpvxOaKmspIIi"  # Replace with your playlist URL    
    csv_file = 'links.csv'  # Path to the CSV file containing video URLs
    output_path = 'fvalue'  # Output directory
    resolution = '360p'  # Desired resolution (e.g., '1080p', '720p', '480p')
    yt_video_url = 'https://www.youtube.com/watch?v=ZxngoItDVt8'


    download_youtube_video(yt_video_url, resolution)
    
s_res = '144'
    # print(web_request(url))
    # download_multi_youtube_videos(csv_file, output_path, resolution)

if __name__ == "__main__":
    main()
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="es-419" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="mkQ_5RDRmzKaIfhQpyGs3g">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# ...

# %%
import tkinter as tk
from tkinter import filedialog

def open_file():
    filepath = filedialog.askopenfilename(initialdir="/", title="Select File", filetypes=(("Text files", "*.txt"), ("All files", "*.*")))
    if filepath:
        # Perform actions with the file
        print("Selected file:", filepath)
        # You can add your own code here to process the file

# Create the main window
window = tk.Tk()

# Create a button for opening the file
open_button = tk.Button(window, text="Open File", command=open_file)
open_button.pack()

# Run the main window's event loop
window.mainloop()
# Out:
# Selected file: C:/Users/AlvaroDLC Work/Documents/19-05-22.txt

# %%
#DISEÑO DE INTERFACE

import tkinter as tk
from tkinter import filedialog
from tkinter import PhotoImage


def open_file():
    filepath = filedialog.askopenfilename(initialdir="/", title="Select File", filetypes=(("Text files", "*.txt"), ("All files", "*.*")))
    if filepath:
        # Perform actions with the file
        print("Selected file:", filepath)
        # You can add your own code here to process the file
    # # Close the window
    # window.destroy()

def get_selected_option():
    selected_option = option.get()
    print("Selected option:", selected_option)

# Create the main window
window = tk.Tk()
window.title("Simple Download - YouTube Videos by Chaskas")
window.geometry("400x300")
window.iconbitmap(False, 'youtube.ico')

# Create a label for the options
label = tk.Label(window, text="Select an option:")
label.pack()

# Create an IntVar to store the selected option
option = tk.IntVar()

# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Create radio buttons for the options
radio_simple = tk.Radiobutton(window, text="Simple video URL", variable=option, value=1)
radio_simple.pack()

# Create entry box
simple_url = tk.Entry()
simple_url.pack()
yt_video_url = simple_url.get()
print(yt_video_url)
# Create a button to get the selected option
option_button = tk.Button(window, text="Get Selected Option", command=get_selected_option)
option_button.pack()


# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------

radio_multiple = tk.Radiobutton(window, text="Multiple links by CSV File", variable=option, value=2)
radio_multiple.pack()

# Create a button for opening the file
open_button = tk.Button(window, text="Open File", command=open_file)
open_button.pack()


# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------

radio_playlist = tk.Radiobutton(window, text="PUBLIC URL Playlist", variable=option, value=3)
radio_playlist.pack()





# Create a button to get the selected option
option_button = tk.Button(window, text="Get Selected Option", command=get_selected_option)
option_button.pack()


# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------


# Run the main window's event loop
window.mainloop()
